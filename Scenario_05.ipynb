# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishek-Shetty-02/DATABRICKS_PYSPARK/blob/main/Scenario_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

spark = SparkSession.builder.appName("Practice").getOrCreate()

# %%
data = [
    ("RCB",),
    ("CSK",),
    ("MI",),
    ("PBKS",),
]

columns = ["team"]
